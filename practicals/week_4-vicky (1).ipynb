# %% [markdown]
# # Convolutional Neural Networks
#
# ## Preliminaries
#
# In this practical session you will implement and train several Convolutional Neural Networks (CNNs) using the Keras framework with a Tensorflow backend. If you are not already familiar with Keras, you can go over the [following tutorial](https://github.com/tueimage/essential-skills/blob/master/keras.md). More detailed information on the different functionalities can be found in the [Keras library documentation](https://keras.io/).
#
# Note that for this set of exercise CPU-only Tensorflow, which you should already have installed, is sufficient (i.e. GPU-support is not required but it will make your experiments run faster).
#
# You are also required to use the `gryds` package for data augmentation that you can install directly from git: `pip install git+https://github.com/tueimage/gryds/`.
#
# You also have to install the Keras deep learning framework (if you have not done so already) by running `conda install keras`. Note that there are two implementations of Keras, one from https://keras.io/ and another one that ships with Tensorflow. Here we use the former.

# %% [markdown]
# ## MNIST
# We will first train a simple CNN to classify handwritten digits using the MNIST dataset. This dataset is often referred to as the "Hello world!" example of deep learning because it can be used to quickly illustrate a small neural network in action (and obtain a decent classification accuracy in the process). More information on it can be found [here](http://yann.lecun.com/exdb/mnist/).
#
# First, let's load the dataset and visualize some images.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.utils import to_categorical

# load the MNIST the dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# scale the image intensities to the 0-1 range
x_train = (x_train / 255.0).astype(np.float32)
x_test = (x_test / 255.0).astype(np.float32)

# convert the data to channel-last
x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# convert the labels to one-hot encoded
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

def plot_images(images, dim=(10, 10), figsize=(10, 10), title=''):
    
    plt.figure(figsize=figsize)
    
    for i in range(images.shape[0]):
        plt.subplot(dim[0], dim[1], i+1)
        plt.imshow(images[i], interpolation='nearest', cmap='gray_r')
        plt.axis('off')
    
    plt.tight_layout()
    plt.suptitle(title)
    plt.show()
    
plot_images(x_train[np.random.randint(0, x_train.shape[0], size=100)].reshape(100, 28, 28))
# Out:
# 2025-10-04 14:14:40.953515: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-04 14:14:41.339455: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-04 14:14:42.356238: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64:
# 2025-10-04 14:14:42.356402: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64:
# 2025-10-04 14:14:42.356413: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# The MNIST classification task is quite simple: given an image, predict the digit that it contains. Thus, this is a 10-class classification problem.
#
# Let's define a simple network for the handwritten digit classification.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 64)       0
#  )
#
#  dropout (Dropout)           (None, 12, 12, 64)        0
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 128)               1179776
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________
# 2025-10-04 14:14:45.289121: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-04 14:14:45.339166: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-04 14:14:45.340147: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-04 14:14:45.342790: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-04 14:14:45.344430: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-04 14:14:45.345267: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-04 14:14:45.345924: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-04 14:14:46.149158: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-04 14:14:46.149967: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-04 14:14:46.150183: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-04 14:14:46.150393: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3344 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 970, pci bus id: 0000:01:00.0, compute capability: 5.2

# %% [markdown]
# Compile and train the network (note that this could take a while).

# %%
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam

model.compile(loss=categorical_crossentropy, optimizer=Adam(), metrics=['accuracy'])

model.fit(x_train, y_train,
          batch_size=128,
          epochs=12,
          verbose=1,
          validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/12
# 2025-10-04 14:14:46.760441: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2025-10-04 14:14:47.380981: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8101
# 469/469 [==============================] - 8s 10ms/step - loss: 0.2447 - accuracy: 0.9251 - val_loss: 0.0544 - val_accuracy: 0.9823
# Epoch 2/12
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0865 - accuracy: 0.9739 - val_loss: 0.0405 - val_accuracy: 0.9868
# Epoch 3/12
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0655 - accuracy: 0.9803 - val_loss: 0.0305 - val_accuracy: 0.9892
# Epoch 4/12
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0546 - accuracy: 0.9832 - val_loss: 0.0304 - val_accuracy: 0.9891
# Epoch 5/12
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0453 - accuracy: 0.9858 - val_loss: 0.0322 - val_accuracy: 0.9893
# Epoch 6/12
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0404 - accuracy: 0.9873 - val_loss: 0.0268 - val_accuracy: 0.9918
# Epoch 7/12
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0365 - accuracy: 0.9889 - val_loss: 0.0280 - val_accuracy: 0.9912
# Epoch 8/12
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0322 - accuracy: 0.9897 - val_loss: 0.0301 - val_accuracy: 0.9905
# Epoch 9/12
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0295 - accuracy: 0.9907 - val_loss: 0.0289 - val_accuracy: 0.9913
# Epoch 10/12
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0261 - accuracy: 0.9921 - val_loss: 0.0311 - val_accuracy: 0.9914
# Epoch 11/12
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0236 - accuracy: 0.9922 - val_loss: 0.0318 - val_accuracy: 0.9910
# Epoch 12/12
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0240 - accuracy: 0.9921 - val_loss: 0.0281 - val_accuracy: 0.9915
# Test loss: 0.028097739443182945
# Test accuracy: 0.9915000200271606

# %% [markdown]
# Now that the model is trained, we can evaluate its performance on the independent test dataset.

# %%
score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.028097739443182945
# Test accuracy: 0.9915000200271606

# %% [markdown]
# ## U-Net
# The U-Net convolutional neural network architecture was first developed for biomedical image segmentation and is to this day one of the most widely used methods for image segmentation. The details of the architecture can be found in the [original paper](https://arxiv.org/abs/1505.04597). In this practical we will build and train a U-Net network that is able to segment blood vessels in retinal images.
#
# ### Loading and visualizing the data
# The data for this task is taken from the [DRIVE](https://www.kaggle.com/datasets/andrewmvd/drive-digital-retinal-images-for-vessel-extraction) database. It consists of photographs of the retina, where the goal is to segment the blood vessels within. The dataset has a total of 40 photographs, divided in 20 images for training and 20 for testing. The images corresponding to the DRIVE test set can be found [here](https://drive.google.com/file/d/1Enau6gb_BtPKCg1Yt5MZIIM18pfVEhxQ/view?usp=sharing).
#
# Let's load the training set and visualize an image with the corresponding blood vessel segmentation. For training we will divide the data in a training and a validation set to monitor the model during training.

# %%
# %matplotlib inline
import sys
sys.path.append('code/')
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from glob import glob
from unet_utils import load_data

# location of the DRIVE dataset
data_folder = './data/DRIVE/'
train_paths = glob(data_folder + 'training/images/*.tif')
images, masks, segmentations = load_data(train_paths)
# Julia - add data


# print the shape of image dataset
print(images.shape)

plt.figure(figsize=(10, 8))

plt.subplot(1, 2, 1)
plt.title("Image of the retina")
plt.axis('off')
plt.imshow(images[0])

plt.subplot(1, 2, 2)
plt.title("Ground truth vessel segmentation")
plt.axis('off')
plt.imshow(segmentations[0][:, :, 0])

plt.show()

# divide in training and validation
train_images, val_images, train_masks, val_masks, train_segmentations, val_segmentations = train_test_split(
    images, masks, segmentations, test_size=0.2, random_state=7)

# print the shape of the training and valudation datasets
print(train_images.shape)
print(train_masks.shape)
print(train_segmentations.shape)
print(val_images.shape)
print(val_masks.shape)
print(val_segmentations.shape)
# Out:
# (20, 584, 565, 3)
# (16, 584, 565, 3)
# (16, 584, 565, 1)
# (16, 584, 565, 1)
# (4, 584, 565, 3)
# (4, 584, 565, 1)
# (4, 584, 565, 1)

# %% [markdown]
# ### Training a U-Net model
#
# You are already provided with implementation of the U-Net architecture in `unet_model.py`. This is a modular implementation and can be used to generate U-Net architectures with a variety of hyperparameters such as depth and number of feature maps. Before using the model, examine the code and documentation and make sure that you understand all the details.
#
# We will train a U-Net model using smaller patches extracted from the training images. Training the images on smaller patches requires less computation power and results in a more varied training dataset (it has the effect of data augmentation by image translation). Because a U-Net is a fully convolutional network it can be evaluated on inputs of different size (the output size will change according to the input size). Thus, although the model will be trained on smaller patches it can still be used to segment larger images with one pass through the model.

# %%
from unet_utils import extract_patches, preprocessing

# work with 32x32 patches
patch_size = (32, 32)

# 200 patches per image
patches_per_im = 200

# visualize a couple of patches as a visual check
patches, patches_segmentations = extract_patches(train_images, train_segmentations, patch_size, patches_per_im=1, seed=7)

print(patches.shape)

fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(12, 12))

for i in range(0, 3):
    axes[i, 0].axis('off')
    axes[i, 0].imshow(patches[i])
    axes[i, 1].axis('off')
    axes[i, 1].imshow(patches_segmentations[i][:, :, 0])
    axes[i, 2].axis('off')
    axes[i, 2].imshow(patches[i+5])
    axes[i, 3].axis('off')
    axes[i, 3].imshow(patches_segmentations[i+5][:, :, 0])

plt.show()
# Out:
# (16, 32, 32, 3)

# %%
# pad the validation data to fit the U-Net model
# images of shape (584, 565) shape result in concatenation error due to the odd number of columns

print("Old shape:", val_images.shape)

val_images, val_masks, val_segmentations = preprocessing(
    val_images, 
    val_masks, 
    val_segmentations, 
    desired_shape=(584, 584))
    
print("New shape:", val_images.shape)
# Out:
# Old shape: (4, 584, 565, 3)
# New shape: (4, 584, 584, 3)

# %%
import os
from unet_model import unet
from unet_utils import datagenerator
from keras.models import load_model
from keras.optimizers import Adam, SGD
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# use a single training image, to better demonstrate the effects of data augmentation
X_train, y_train = np.expand_dims(train_images[0], axis=0), np.expand_dims(train_segmentations[0], axis=0)

print(X_train.shape)
print(y_train.shape)

# hyperparameters
depth = 3
channels = 32
use_batchnorm = True
batch_size = 64
epochs = 250
steps_per_epoch = int(np.ceil((patches_per_im * len(train_images)) / batch_size))

# work with 32x32 patches
patch_size = (32, 32)
# 200 patches per image
patches_per_im = 200

# initialize model
model = unet(input_shape=(None, None, 3), depth=depth, channels=channels, batchnorm=use_batchnorm)

# print a summary of the model
# model.summary(line_length=120)

# compile the model
model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# stop the training if the validation loss does not increase for 15 consecutive epochs
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# train the model with the data generator, and save the training history
history = model.fit(datagenerator(X_train, y_train, patch_size, patches_per_im, batch_size),
                              validation_data=(val_images, val_segmentations),
                              steps_per_epoch=steps_per_epoch, epochs=epochs, verbose=2,
                              callbacks=[early_stopping])
# Out:
# (1, 584, 565, 3)
# (1, 584, 565, 1)
# Epoch 1/250
# 2025-10-04 14:15:51.239993: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.94GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 50/50 - 8s - loss: 0.5071 - accuracy: 0.8181 - val_loss: 0.3923 - val_accuracy: 0.9176 - 8s/epoch - 155ms/step
# Epoch 2/250
# 2025-10-04 14:15:54.882481: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.94GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 50/50 - 2s - loss: 0.2822 - accuracy: 0.9493 - val_loss: 0.2868 - val_accuracy: 0.9176 - 2s/epoch - 34ms/step
# Epoch 3/250
# 50/50 - 2s - loss: 0.2074 - accuracy: 0.9570 - val_loss: 0.2724 - val_accuracy: 0.9176 - 2s/epoch - 35ms/step
# Epoch 4/250
# 50/50 - 2s - loss: 0.1619 - accuracy: 0.9600 - val_loss: 0.2789 - val_accuracy: 0.9176 - 2s/epoch - 34ms/step
# Epoch 5/250
# 50/50 - 2s - loss: 0.1489 - accuracy: 0.9590 - val_loss: 0.9124 - val_accuracy: 0.5342 - 2s/epoch - 34ms/step
# Epoch 6/250
# 50/50 - 2s - loss: 0.1301 - accuracy: 0.9605 - val_loss: 0.2708 - val_accuracy: 0.9176 - 2s/epoch - 34ms/step
# Epoch 7/250
# 50/50 - 2s - loss: 0.1431 - accuracy: 0.9537 - val_loss: 0.3435 - val_accuracy: 0.9176 - 2s/epoch - 34ms/step
# Epoch 8/250
# 50/50 - 2s - loss: 0.1194 - accuracy: 0.9604 - val_loss: 0.2936 - val_accuracy: 0.9184 - 2s/epoch - 34ms/step
# Epoch 9/250
# 50/50 - 2s - loss: 0.1164 - accuracy: 0.9603 - val_loss: 0.2733 - val_accuracy: 0.9253 - 2s/epoch - 35ms/step
# Epoch 10/250
# 50/50 - 2s - loss: 0.1053 - accuracy: 0.9632 - val_loss: 0.3514 - val_accuracy: 0.9229 - 2s/epoch - 34ms/step
# Epoch 11/250
# 50/50 - 2s - loss: 0.0979 - accuracy: 0.9646 - val_loss: 0.3128 - val_accuracy: 0.9219 - 2s/epoch - 35ms/step
# Epoch 12/250
# 50/50 - 2s - loss: 0.0988 - accuracy: 0.9642 - val_loss: 0.3107 - val_accuracy: 0.9246 - 2s/epoch - 34ms/step
# Epoch 13/250
# 50/50 - 2s - loss: 0.0984 - accuracy: 0.9639 - val_loss: 0.2354 - val_accuracy: 0.9339 - 2s/epoch - 35ms/step
# Epoch 14/250
# 50/50 - 2s - loss: 0.0964 - accuracy: 0.9639 - val_loss: 0.1872 - val_accuracy: 0.9443 - 2s/epoch - 34ms/step
# Epoch 15/250
# 50/50 - 2s - loss: 0.0990 - accuracy: 0.9635 - val_loss: 0.2495 - val_accuracy: 0.9342 - 2s/epoch - 34ms/step
# Epoch 16/250
# 50/50 - 2s - loss: 0.0961 - accuracy: 0.9640 - val_loss: 1.0164 - val_accuracy: 0.6460 - 2s/epoch - 34ms/step
# Epoch 17/250
# 50/50 - 2s - loss: 0.1019 - accuracy: 0.9624 - val_loss: 0.2228 - val_accuracy: 0.9421 - 2s/epoch - 35ms/step
# Epoch 18/250
# 50/50 - 2s - loss: 0.0932 - accuracy: 0.9647 - val_loss: 0.5588 - val_accuracy: 0.7123 - 2s/epoch - 34ms/step
# Epoch 19/250
# 50/50 - 2s - loss: 0.0881 - accuracy: 0.9663 - val_loss: 0.2649 - val_accuracy: 0.9387 - 2s/epoch - 35ms/step
# Epoch 20/250
# 50/50 - 2s - loss: 0.0867 - accuracy: 0.9665 - val_loss: 0.3110 - val_accuracy: 0.9353 - 2s/epoch - 34ms/step
# Epoch 21/250
# 50/50 - 2s - loss: 0.0828 - accuracy: 0.9680 - val_loss: 0.2757 - val_accuracy: 0.9344 - 2s/epoch - 35ms/step
# Epoch 22/250
# 50/50 - 2s - loss: 0.0816 - accuracy: 0.9681 - val_loss: 0.2057 - val_accuracy: 0.9410 - 2s/epoch - 34ms/step
# Epoch 23/250
# 50/50 - 2s - loss: 0.0822 - accuracy: 0.9678 - val_loss: 0.2389 - val_accuracy: 0.9383 - 2s/epoch - 35ms/step
# Epoch 24/250
# 50/50 - 2s - loss: 0.0762 - accuracy: 0.9699 - val_loss: 0.2462 - val_accuracy: 0.9378 - 2s/epoch - 34ms/step
# Epoch 25/250
# 50/50 - 2s - loss: 0.0790 - accuracy: 0.9688 - val_loss: 0.1569 - val_accuracy: 0.9463 - 2s/epoch - 35ms/step
# Epoch 26/250
# 50/50 - 2s - loss: 0.0903 - accuracy: 0.9656 - val_loss: 0.6928 - val_accuracy: 0.7970 - 2s/epoch - 34ms/step
# Epoch 27/250
# 50/50 - 2s - loss: 0.0966 - accuracy: 0.9635 - val_loss: 0.2555 - val_accuracy: 0.9222 - 2s/epoch - 34ms/step
# Epoch 28/250
# 50/50 - 2s - loss: 0.0963 - accuracy: 0.9633 - val_loss: 0.2816 - val_accuracy: 0.9290 - 2s/epoch - 34ms/step
# Epoch 29/250
# 50/50 - 2s - loss: 0.0967 - accuracy: 0.9631 - val_loss: 0.1683 - val_accuracy: 0.9470 - 2s/epoch - 35ms/step
# Epoch 30/250
# 50/50 - 2s - loss: 0.0823 - accuracy: 0.9681 - val_loss: 0.2168 - val_accuracy: 0.9417 - 2s/epoch - 34ms/step
# Epoch 31/250
# 50/50 - 2s - loss: 0.0827 - accuracy: 0.9671 - val_loss: 0.2644 - val_accuracy: 0.9345 - 2s/epoch - 35ms/step
# Epoch 32/250
# 50/50 - 2s - loss: 0.0813 - accuracy: 0.9677 - val_loss: 0.2677 - val_accuracy: 0.9369 - 2s/epoch - 34ms/step
# Epoch 33/250
# 50/50 - 2s - loss: 0.0783 - accuracy: 0.9687 - val_loss: 0.2902 - val_accuracy: 0.9326 - 2s/epoch - 35ms/step
# Epoch 34/250
# 50/50 - 2s - loss: 0.0827 - accuracy: 0.9672 - val_loss: 0.2895 - val_accuracy: 0.9307 - 2s/epoch - 34ms/step
# Epoch 35/250
# 50/50 - 2s - loss: 0.0742 - accuracy: 0.9702 - val_loss: 0.3136 - val_accuracy: 0.9323 - 2s/epoch - 35ms/step
# Epoch 36/250
# 50/50 - 2s - loss: 0.0750 - accuracy: 0.9699 - val_loss: 0.2664 - val_accuracy: 0.9335 - 2s/epoch - 34ms/step
# Epoch 37/250
# 50/50 - 2s - loss: 0.0715 - accuracy: 0.9712 - val_loss: 0.2588 - val_accuracy: 0.9371 - 2s/epoch - 35ms/step
# Epoch 38/250
# 50/50 - 2s - loss: 0.0722 - accuracy: 0.9707 - val_loss: 0.2882 - val_accuracy: 0.9325 - 2s/epoch - 34ms/step
# Epoch 39/250
# 50/50 - 2s - loss: 0.0682 - accuracy: 0.9724 - val_loss: 0.2866 - val_accuracy: 0.9336 - 2s/epoch - 35ms/step
# Epoch 40/250
# 50/50 - 2s - loss: 0.0727 - accuracy: 0.9704 - val_loss: 0.3339 - val_accuracy: 0.9273 - 2s/epoch - 35ms/step

# %% [markdown]
# ### Visualizing the segmentation results

# %%
# run the model on one test image and show the results
from unet_utils import preprocessing

# test data paths
impaths_test = glob(data_folder + 'test/images/*.tif')

# load data
test_images, test_masks, test_segmentations = load_data(impaths_test, test=True)

# pad the data to fit the U-Net model
test_images, test_masks, test_segmentations = preprocessing(test_images, test_masks, test_segmentations, 
                                                            desired_shape=(584, 584))

# use a single image to evaluate
X_test, y_test = np.expand_dims(test_images[0], axis=0), np.expand_dims(test_masks[0], axis=0)

# predict test samples
test_prediction = model.predict(X_test, batch_size=4)

# visualize the test result
plt.figure(figsize=(12, 10))

plt.subplot(1, 3, 1)
plt.title("Image of the retina")
plt.axis('off')
plt.imshow(test_images[0])

plt.subplot(1, 3, 2)
plt.title("Ground truth vessel segmentation")
plt.axis('off')
plt.imshow(test_segmentations[0][:, :, 0])

plt.subplot(1, 3, 3)
plt.title("Predicted vessel segmentation")
plt.axis('off')
plt.imshow(test_prediction[0, :, :, 0])

plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step

# %% [markdown]
# # Exercises
#
# ## Number of parameters
#
# The first convolutional layer in the MNIST example has 320 parameters. The first fully connected layer has 1179,776 parameters. What do these parameters correspond to?
#
# <font color='#770a0a'>What is the general expression for the number of parameters of 1) a convolutional layer and 2) a fully-connected layer?</font>
#
# ## Fully-convolutional MNIST model
#
# Modify the model in the MNIST example in such a way that it only contains convolutional layers while keeping the same number of parameters. If you do the modification correctly, the two models will have the same behaviour (i.e. they will represent the same model, only with different implementation). Show this experimentally.
#
#
# ## U-Net architecture
#
# <font color='#770a0a'> What is the role of the skip connections in the U-Net neural network architecture? Will it be possible to train the exact same architecture with the skip connections omitted? If yes, what would be the expected result? If no, what would be the cause of the error?</font>
#
# ## Data augmentation
#
# <font color='#770a0a'>Why does data augmentation result in less overfitting? Can data augmentation be applied to the test samples? If yes, towards what goal? If no, what is preventing that?</font>
#
#
# Implement random brightness augmentation of the image data by adding a random offset to the image intensity before passing them trough the network at training time. Train a model with random brightness augmentation and compare it to the baseline above.
#
# Implement data augmentation procedure that in addition to brightness augmentation also performs b-spline geometric augmentation using the [`gryds`](https://github.com/tueimage/gryds) package (you can look at the documentation of the package for an example on how to do that). Compare the new model with the baseline and the model that only performs brightness augmentation.

# %% [markdown]
# ### Number of parameters
# ***SOLUTION:***
#
# The number of parameters in a convolutional layer is:
# $$p_{conv} = K_w\cdot K_h \cdot C_{in}\cdot C_{out} + C_{out}$$
# , where $K_w$ and $K_h$ are the kernel widht and height respectively and $C_{in}$ and $C_{out}$ are the input and output channels repectively.
#
# The number of parameters in a fully-connected layer (dense) is:
# $$p_{fully} = N_{in}\cdot N_{out} + N_{out}$$
# , where $N_{in}$ and $N_{out}$ are the input and output channels respectively.

# %% [markdown]
# ### Fully-convolutional MNIST model
# ***SOLUTION:***

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam

# We substitue the model to contain convolutional layers
modf = Sequential()
# same as original
modf.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
# added stride to accomplish max pooling effect
modf.add(Conv2D(64, (3, 3),(2,2), activation='relu',))
# calculated kernel size based on same 128 output channels
modf.add(Conv2D(128, (12,12), activation='relu'))
# calculated kernel size based on same 10 output channels
modf.add(Conv2D(10, (1,1), activation='softmax'))
# flatten so compatible with y-targets
modf.add(Flatten())

modf.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 26, 26, 32)        320
#
#  conv2d_21 (Conv2D)          (None, 12, 12, 64)        18496
#
#  conv2d_22 (Conv2D)          (None, 1, 1, 128)         1179776
#
#  conv2d_23 (Conv2D)          (None, 1, 1, 10)          1290
#
#  flatten_1 (Flatten)         (None, 10)                0
#
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam

# load the MNIST the dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# scale the image intensities to the 0-1 range
x_train = (x_train / 255.0).astype(np.float32)
x_test = (x_test / 255.0).astype(np.float32)

# convert the data to channel-last
x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# convert the labels to one-hot encoded
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

modf.compile(loss=categorical_crossentropy, optimizer=Adam(), metrics=['accuracy'])

modf.fit(x_train, y_train,
          batch_size=128,
          epochs=12,
          verbose=1,
          validation_data=(x_test, y_test))

score = modf.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/12
# 469/469 [==============================] - 5s 10ms/step - loss: 0.1668 - accuracy: 0.9505 - val_loss: 0.0573 - val_accuracy: 0.9811
# Epoch 2/12
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0451 - accuracy: 0.9862 - val_loss: 0.0412 - val_accuracy: 0.9863
# Epoch 3/12
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0277 - accuracy: 0.9915 - val_loss: 0.0346 - val_accuracy: 0.9883
# Epoch 4/12
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0181 - accuracy: 0.9940 - val_loss: 0.0381 - val_accuracy: 0.9879
# Epoch 5/12
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0117 - accuracy: 0.9965 - val_loss: 0.0391 - val_accuracy: 0.9882
# Epoch 6/12
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0108 - accuracy: 0.9964 - val_loss: 0.0422 - val_accuracy: 0.9883
# Epoch 7/12
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.0482 - val_accuracy: 0.9887
# Epoch 8/12
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0064 - accuracy: 0.9979 - val_loss: 0.0542 - val_accuracy: 0.9864
# Epoch 9/12
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0409 - val_accuracy: 0.9899
# Epoch 10/12
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 0.0469 - val_accuracy: 0.9886
# Epoch 11/12
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.0515 - val_accuracy: 0.9877
# Epoch 12/12
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0491 - val_accuracy: 0.9888
# Test loss: 0.04906192794442177
# Test accuracy: 0.9887999892234802

# %% [markdown]
# NOTE: MAYBE NEEDED MORE EXPLANATION?Like the math or something
# Should do the training part?

# %% [markdown]
# ### U-Net architecture
# ***SOLUTION:***

# %% [markdown]
# ### Data augmentation
# ***SOLUTION:***

# %%
# %matplotlib inline
import sys
sys.path.append('code/')
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from glob import glob
from unet_utils import load_data
from unet_utils import extract_patches, preprocessing
import os
from unet_model import unet
from unet_utils import datagenerator
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import random
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from unet_utils import preprocessing
import gryds

# %% [markdown]
# Load dataset.

# %%
# location of the DRIVE dataset
data_folder = 'data/DRIVE/'
train_paths = glob(data_folder + 'training/images/*.tif')
images, masks, segmentations = load_data(train_paths)

# divide in training and validation
train_images, val_images, train_masks, val_masks, train_segmentations, val_segmentations = train_test_split(
    images, masks, segmentations, test_size=0.2, random_state=7)

# %% [markdown]
# Create patches.

# %%
# work with 32x32 patches
patch_size = (32, 32)

# 200 patches per image
patches_per_im = 200

# visualize a couple of patches as a visual check
patches, patches_segmentations = extract_patches(train_images, train_segmentations, patch_size, patches_per_im=1, seed=7)

print(patches.shape)

fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(12, 12))

for i in range(0, 3):
    axes[i, 0].axis('off')
    axes[i, 0].imshow(patches[i])
    axes[i, 1].axis('off')
    axes[i, 1].imshow(patches_segmentations[i][:, :, 0])
    axes[i, 2].axis('off')
    axes[i, 2].imshow(patches[i+5])
    axes[i, 3].axis('off')
    axes[i, 3].imshow(patches_segmentations[i+5][:, :, 0])

plt.show()
# Out:
# (16, 32, 32, 3)

# %%
# pad the validation data to fit the U-Net model
# images of shape (584, 565) shape result in concatenation error due to the odd number of columns

val_images, val_masks, val_segmentations = preprocessing(
    val_images, 
    val_masks, 
    val_segmentations, 
    desired_shape=(584, 584))

# %% [markdown]
# Apply brigthness augmentation to a single training data.

# %%
# use a single training image, to better demonstrate the effects of data augmentation
X_train, y_train = np.expand_dims(train_images[0], axis=0), np.expand_dims(train_segmentations[0], axis=0)

# add new samples from original sample with random brightness
N = 5

new_training_x = []
new_training_y =  []
tmp_target = y_train[0,:,:,:]

    
for n in range(N):
    rFac = random.uniform(0.3, 3)
    tmp_smple = X_train[0,:,:,:] * rFac
    tmp_smple = np.clip(tmp_smple, 0, 1)
    new_training_x.append(tmp_smple)
    new_training_y.append(y_train[0])
    plt.title(f"Image of the retina {n + 1}")
    plt.axis('off')
    plt.imshow(tmp_smple)
    plt.show()

plt.title("Image of the target")
plt.axis('off')
plt.imshow(tmp_target)
plt.show()

new_training_x = np.stack(new_training_x, axis=0)
new_training_y = np.stack(new_training_y, axis=0)

# %% [markdown]
# Define U-net structure.

# %%
# hyperparameters
depth = 3
channels = 32
use_batchnorm = True
batch_size = 64
epochs = 250
steps_per_epoch = int(np.ceil((patches_per_im * len(train_images)) / batch_size))

# work with 32x32 patches
patch_size = (32, 32)
# 200 patches per image
patches_per_im = 200

# initialize model
model = unet(input_shape=(None, None, 3), depth=depth, channels=channels, batchnorm=use_batchnorm)

# compile the model
model.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# stop the training if the validation loss does not increase for 15 consecutive epochs
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

# %%
# train the model with the data generator, and save the training history
history = model.fit(datagenerator(new_training_x, new_training_y, patch_size, patches_per_im, batch_size),
                              validation_data=(val_images, val_segmentations),
                              steps_per_epoch=steps_per_epoch, epochs=epochs, verbose=1,
                              callbacks=[early_stopping])
# Out:
# Epoch 1/250
# 2025-10-04 14:18:01.065686: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x2f11bd40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-10-04 14:18:01.065706: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce GTX 970, Compute Capability 5.2
# 2025-10-04 14:18:01.096135: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-10-04 14:18:01.363468: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 50/50 [==============================] - 8s 57ms/step - loss: 0.5931 - accuracy: 0.7502 - val_loss: 0.5243 - val_accuracy: 0.9176
# Epoch 2/250
# 50/50 [==============================] - 2s 41ms/step - loss: 0.3665 - accuracy: 0.9217 - val_loss: 0.3238 - val_accuracy: 0.9176
# Epoch 3/250
# 50/50 [==============================] - 2s 42ms/step - loss: 0.2592 - accuracy: 0.9412 - val_loss: 0.3122 - val_accuracy: 0.9176
# Epoch 4/250
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1961 - accuracy: 0.9497 - val_loss: 0.2681 - val_accuracy: 0.9177
# Epoch 5/250
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1750 - accuracy: 0.9485 - val_loss: 0.2682 - val_accuracy: 0.9176
# Epoch 6/250
# 50/50 [==============================] - 2s 42ms/step - loss: 0.1519 - accuracy: 0.9526 - val_loss: 0.2601 - val_accuracy: 0.9174
# Epoch 7/250
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1361 - accuracy: 0.9569 - val_loss: 0.3334 - val_accuracy: 0.9179
# Epoch 8/250
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1299 - accuracy: 0.9561 - val_loss: 0.3400 - val_accuracy: 0.9182
# Epoch 9/250
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1175 - accuracy: 0.9598 - val_loss: 0.3287 - val_accuracy: 0.9215
# Epoch 10/250
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1104 - accuracy: 0.9617 - val_loss: 0.3489 - val_accuracy: 0.9179
# Epoch 11/250
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1090 - accuracy: 0.9607 - val_loss: 0.3229 - val_accuracy: 0.9199
# Epoch 12/250
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1005 - accuracy: 0.9634 - val_loss: 0.3697 - val_accuracy: 0.9191
# Epoch 13/250
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1020 - accuracy: 0.9625 - val_loss: 0.2964 - val_accuracy: 0.9267
# Epoch 14/250
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1015 - accuracy: 0.9620 - val_loss: 0.3035 - val_accuracy: 0.9296
# Epoch 15/250
# 50/50 [==============================] - 2s 41ms/step - loss: 0.0965 - accuracy: 0.9640 - val_loss: 0.3318 - val_accuracy: 0.9195
# Epoch 16/250
# 50/50 [==============================] - 2s 41ms/step - loss: 0.1062 - accuracy: 0.9602 - val_loss: 0.3070 - val_accuracy: 0.9192
# Epoch 17/250
# 50/50 [==============================] - 2s 41ms/step - loss: 0.0925 - accuracy: 0.9654 - val_loss: 0.3329 - val_accuracy: 0.9216
# Epoch 18/250
# 50/50 [==============================] - 2s 41ms/step - loss: 0.0874 - accuracy: 0.9671 - val_loss: 0.3242 - val_accuracy: 0.9296
# Epoch 19/250
# 50/50 [==============================] - 2s 41ms/step - loss: 0.0842 - accuracy: 0.9677 - val_loss: 0.2807 - val_accuracy: 0.9332
# Epoch 20/250
# 50/50 [==============================] - 2s 41ms/step - loss: 0.0833 - accuracy: 0.9674 - val_loss: 0.2696 - val_accuracy: 0.9309
# Epoch 21/250
# 50/50 [==============================] - 2s 42ms/step - loss: 0.0795 - accuracy: 0.9693 - val_loss: 0.3000 - val_accuracy: 0.9290

# %% [markdown]
# Show the prediction performance for one test image.

# %%
# test data paths
impaths_test = glob(data_folder + 'test/images/*.tif')

# load data
test_images, test_masks, test_segmentations = load_data(impaths_test, test=True)

# pad the data to fit the U-Net model
test_images, test_masks, test_segmentations = preprocessing(test_images, test_masks, test_segmentations, 
                                                            desired_shape=(584, 584))

# use a single image to evaluate
X_test, y_test = np.expand_dims(test_images[0], axis=0), np.expand_dims(test_masks[0], axis=0)

# predict test samples
test_prediction = model.predict(X_test, batch_size=4)

# visualize the test result
plt.figure(figsize=(12, 10))

plt.subplot(1, 3, 1)
plt.title("Image of the retina")
plt.axis('off')
plt.imshow(test_images[0])

plt.subplot(1, 3, 2)
plt.title("Ground truth vessel segmentation")
plt.axis('off')
plt.imshow(test_segmentations[0][:, :, 0])

plt.subplot(1, 3, 3)
plt.title("Predicted vessel segmentation")
plt.axis('off')
plt.imshow(test_prediction[0, :, :, 0])

plt.show()
# Out:
# 1/1 [==============================] - 0s 134ms/step

# %% [markdown]
# B-spline transformation as data augmentation.

# %%
# use a single training image, to better demonstrate the effects of data augmentation
X_train, y_train = np.expand_dims(train_images[0], axis=0), np.expand_dims(train_segmentations[0], axis=0)

# add new samples from original sample with random brightness
N_mean = 5

new_training_x = []
new_training_y =  []

for n in range(N_mean):
    rFac = random.uniform(0.3, 3)
    tmp_smple = X_train[0, :, :, :] * rFac
    tmp_smple = np.clip(tmp_smple, 0, 1)
    
    tmp_target = y_train[0, :, :, :]

    disp_i = np.random.uniform(-0.1, 0.1, size=[3, 3])
    disp_j = np.random.uniform(-0.1, 0.1, size=[3, 3])

    a_bspline_transformation = gryds.BSplineTransformation([disp_i, disp_j])
    channel_y = tmp_target[:, :, 0]
    interpolator_y = gryds.Interpolator(channel_y)
    a_deformed_target = interpolator_y.transform(a_bspline_transformation)
    
    # Transform each channel separately for colored images
    deformed_channels_x = []
    for c in range(tmp_smple.shape[-1]):   # loop over RGB channels
        channel_x = tmp_smple[:, :, c]
        interpolator_x = gryds.Interpolator(channel_x)
        deformed_channel_x = interpolator_x.transform(a_bspline_transformation)
        deformed_channels_x.append(deformed_channel_x)

    # Stack back into RGB
    a_deformed_image = np.stack(deformed_channels_x, axis=-1)
    a_deformed_image = np.clip(a_deformed_image, 0.0, 1.0)
    
    new_training_x.append(a_deformed_image)
    new_training_y.append(a_deformed_target)
    plt.title("Image of the retina")
    plt.axis('off')
    plt.imshow(a_deformed_image)
    plt.show()
    plt.title("Image of the target")
    plt.axis('off')
    plt.imshow(a_deformed_target)
    plt.show()
    

new_training_x = np.stack(new_training_x, axis=0)
new_training_y = np.stack(new_training_y, axis=0)

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# train the model with the data generator, and save the training history
history = model.fit(datagenerator(new_training_x, new_training_y, patch_size, patches_per_im, batch_size),
                              validation_data=(val_images, val_segmentations),
                              steps_per_epoch=steps_per_epoch, epochs=epochs, verbose=2,
                              callbacks=[early_stopping])
# Out:
# Epoch 1/250
# 50/50 - 14s - loss: 0.1563 - accuracy: 0.1125 - val_loss: 4.4158 - val_accuracy: 0.6146 - 14s/epoch - 273ms/step
# Epoch 2/250
# 50/50 - 9s - loss: 0.1460 - accuracy: 0.0988 - val_loss: 0.3674 - val_accuracy: 0.9185 - 9s/epoch - 183ms/step
# Epoch 3/250
# 50/50 - 7s - loss: 0.1446 - accuracy: 0.1064 - val_loss: 0.2312 - val_accuracy: 0.9236 - 7s/epoch - 149ms/step
# Epoch 4/250
# 50/50 - 7s - loss: 0.1241 - accuracy: 0.1127 - val_loss: 0.2142 - val_accuracy: 0.9333 - 7s/epoch - 149ms/step
# Epoch 5/250
# 50/50 - 7s - loss: 0.1199 - accuracy: 0.1040 - val_loss: 0.3149 - val_accuracy: 0.9211 - 7s/epoch - 149ms/step
# Epoch 6/250
# 50/50 - 7s - loss: 0.1153 - accuracy: 0.1038 - val_loss: 0.2393 - val_accuracy: 0.9282 - 7s/epoch - 149ms/step
# Epoch 7/250
# 50/50 - 7s - loss: 0.1152 - accuracy: 0.1021 - val_loss: 0.2294 - val_accuracy: 0.9362 - 7s/epoch - 149ms/step
# Epoch 8/250
# 50/50 - 7s - loss: 0.1172 - accuracy: 0.1063 - val_loss: 0.3016 - val_accuracy: 0.9285 - 7s/epoch - 148ms/step
# Epoch 9/250
# 50/50 - 8s - loss: 0.1022 - accuracy: 0.1242 - val_loss: 0.3627 - val_accuracy: 0.9204 - 8s/epoch - 166ms/step
# Epoch 10/250
# 50/50 - 7s - loss: 0.1061 - accuracy: 0.0992 - val_loss: 0.2500 - val_accuracy: 0.9344 - 7s/epoch - 150ms/step
# Epoch 11/250
# 50/50 - 7s - loss: 0.0983 - accuracy: 0.1123 - val_loss: 0.4091 - val_accuracy: 0.9233 - 7s/epoch - 149ms/step
# Epoch 12/250
# 50/50 - 7s - loss: 0.0941 - accuracy: 0.1164 - val_loss: 0.3619 - val_accuracy: 0.9283 - 7s/epoch - 149ms/step
# Epoch 13/250
# 50/50 - 7s - loss: 0.0983 - accuracy: 0.1103 - val_loss: 0.4117 - val_accuracy: 0.9264 - 7s/epoch - 149ms/step
# Epoch 14/250
# 50/50 - 7s - loss: 0.0913 - accuracy: 0.1105 - val_loss: 0.3951 - val_accuracy: 0.9238 - 7s/epoch - 149ms/step
# Epoch 15/250
# 50/50 - 7s - loss: 0.0953 - accuracy: 0.1065 - val_loss: 0.5015 - val_accuracy: 0.9192 - 7s/epoch - 149ms/step
# Epoch 16/250
# 50/50 - 7s - loss: 0.0932 - accuracy: 0.1114 - val_loss: 0.2724 - val_accuracy: 0.9356 - 7s/epoch - 148ms/step
# Epoch 17/250
# 50/50 - 8s - loss: 0.0895 - accuracy: 0.1104 - val_loss: 0.4520 - val_accuracy: 0.9201 - 8s/epoch - 166ms/step
# Epoch 18/250
# 50/50 - 7s - loss: 0.0884 - accuracy: 0.1150 - val_loss: 0.2614 - val_accuracy: 0.9363 - 7s/epoch - 149ms/step
# Epoch 19/250
# 50/50 - 8s - loss: 0.0888 - accuracy: 0.1037 - val_loss: 0.2802 - val_accuracy: 0.9355 - 8s/epoch - 150ms/step

# %%
# run the model on one test image and show the results
from unet_utils import preprocessing

# test data paths
impaths_test = glob(data_folder + 'test/images/*.tif')

# load data
test_images, test_masks, test_segmentations = load_data(impaths_test, test=True)

# pad the data to fit the U-Net model
test_images, test_masks, test_segmentations = preprocessing(test_images, test_masks, test_segmentations, 
                                                            desired_shape=(584, 584))

# use a single image to evaluate
X_test, y_test = np.expand_dims(test_images[0], axis=0), np.expand_dims(test_masks[0], axis=0)

# predict test samples
test_prediction = model.predict(X_test, batch_size=4)

# visualize the test result
plt.figure(figsize=(12, 10))

plt.subplot(1, 3, 1)
plt.title("Image of the retina")
plt.axis('off')
plt.imshow(test_images[0])

plt.subplot(1, 3, 2)
plt.title("Ground truth vessel segmentation")
plt.axis('off')
plt.imshow(test_segmentations[0][:, :, 0])

plt.subplot(1, 3, 3)
plt.title("Predicted vessel segmentation")
plt.axis('off')
plt.imshow(test_prediction[0, :, :, 0])

plt.show()
# Out:
# 1/1 [==============================] - 0s 23ms/step
